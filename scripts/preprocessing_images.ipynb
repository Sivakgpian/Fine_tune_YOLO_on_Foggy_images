# %%
pip install opencv-python numpy scikit-image
# Out:
# Requirement already satisfied: opencv-python in c:\users\korra\anaconda3\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy in c:\users\korra\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: scikit-image in c:\users\korra\anaconda3\lib\site-packages (0.24.0)
# Requirement already satisfied: scipy>=1.9 in c:\users\korra\anaconda3\lib\site-packages (from scikit-image) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in c:\users\korra\anaconda3\lib\site-packages (from scikit-image) (3.3)
# Requirement already satisfied: pillow>=9.1 in c:\users\korra\anaconda3\lib\site-packages (from scikit-image) (10.4.0)
# Requirement already satisfied: imageio>=2.33 in c:\users\korra\anaconda3\lib\site-packages (from scikit-image) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\korra\anaconda3\lib\site-packages (from scikit-image) (2023.4.12)
# Requirement already satisfied: packaging>=21 in c:\users\korra\anaconda3\lib\site-packages (from scikit-image) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\korra\anaconda3\lib\site-packages (from scikit-image) (0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !dir
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 3893-BB6D
#
#  Directory of C:\Users\korra\Downloads\YOLO_fine_tune
#
# 27-05-2025  13:12    <DIR>          .
# 27-05-2025  12:28    <DIR>          ..
# 27-05-2025  12:33    <DIR>          .ipynb_checkpoints
# 27-05-2025  13:13    <DIR>          Clean_outputs
# 27-05-2025  10:18    <DIR>          data_annotated
# 27-05-2025  12:35            34,202 dehazing.ipynb
# 27-05-2025  12:13           343,533 fine_tuning_YOLO.ipynb
# 27-05-2025  07:33    <DIR>          Foggy_Cityscapes
# 27-05-2025  13:12            17,393 preprocessing_images.ipynb
# 27-05-2025  10:49    <DIR>          runs
# 27-05-2025  10:49        22,588,772 yolov8s.pt
#                4 File(s)     22,983,900 bytes
#                7 Dir(s)  72,133,443,584 bytes free

# %%
import cv2
import numpy as np
import os
import csv
import math
from skimage.metrics import mean_squared_error 
from skimage import io, img_as_float

# %%
def calculate_entropy(image_gray):
    if image_gray is None:
        return None
    hist = cv2.calcHist([image_gray], [0], None, [256], [0, 256])
    hist_norm = hist.ravel() / hist.sum()
    entropy = -np.sum(hist_norm * np.log2(hist_norm + np.finfo(float).eps))
    return entropy

# %%
def dark_channel(im, patch_size):
    b, g, r = cv2.split(im)
    dc = np.minimum(np.minimum(r, g), b)
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (patch_size, patch_size))
    dark = cv2.erode(dc, kernel)
    return dark

# %%
def atmospheric_light(im, dark_channel_img, p=0.001):
    im_flat = im.reshape(-1, 3)
    dark_flat = dark_channel_img.flatten()
    num_pixels = dark_flat.shape[0]
    num_search_pixels = int(max(math.floor(num_pixels * p), 1))
    indices = np.argsort(dark_flat)[-num_search_pixels:]
    atm_sum = np.zeros(3)
    for idx in indices:
        atm_sum += im_flat[idx]
    A = atm_sum / num_search_pixels
    return A.astype(np.float32)

# %%
def dehaze_dcp(image, patch_size=15, omega=0.95, t0=0.1, refine_radius=40):
    if image is None:
        print("Error: DCP received a None image.")
        return None
    
    original_dtype = image.dtype
    if not np.issubdtype(original_dtype, np.uint8):
        print(f"Warning: DCP input image is not uint8 ({original_dtype}), converting. This might affect results.")
        image = cv2.normalize(image, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)

    img_float_01 = image.astype(np.float32) / 255.0 # DCP works well with [0,1] range

    dc = dark_channel(image, patch_size) # Dark channel on original 0-255 image
    A = atmospheric_light(image, dc, p=0.001) # Atmospheric light from original 0-255 image

    A_01 = A / 255.0
    im_norm_by_A = np.empty_like(img_float_01)
    for i in range(3):
        if A_01[i] > 1e-5:
            im_norm_by_A[:,:,i] = img_float_01[:,:,i] / A_01[i]
        else:
            im_norm_by_A[:,:,i] = img_float_01[:,:,i] # Avoid division by zero

    transmission_raw = 1 - omega * (dark_channel( (im_norm_by_A * 255).astype(np.uint8) , patch_size) / 255.0) # Dark channel of normalized image
    transmission = np.maximum(transmission_raw, t0)

    # Refine transmission
    try:
        import cv2.ximgproc
        gray_guide = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY).astype(np.float32) / 255.0
        refined_t = cv2.ximgproc.guidedFilter(guide=gray_guide,
                                              src=transmission.astype(np.float32),
                                              radius=refine_radius,
                                              eps=0.001) # Regularization
    except (ImportError, AttributeError, cv2.error) as e:
        if transmission.ndim == 3 and transmission.shape[2] == 1:
            t_for_blur = transmission[:,:,0].astype(np.float32)
        elif transmission.ndim == 2:
            t_for_blur = transmission.astype(np.float32)
        else: # Fallback if transmission is unexpectedly multi-channel > 1
            t_for_blur = cv2.cvtColor(transmission.astype(np.float32), cv2.COLOR_BGR2GRAY)

        refined_t_blur = cv2.medianBlur(t_for_blur, 2 * (refine_radius // 2) + 1) # Kernel size must be odd
        if refined_t_blur.ndim == 2: 
             refined_t = refined_t_blur
        else:
             refined_t = refined_t_blur


  
    if refined_t.ndim == 2:
        t_broadcast = refined_t[:, :, np.newaxis] # Make it (H, W, 1) for broadcasting
    elif refined_t.shape[2] == 1:
        t_broadcast = refined_t
    else: # If refined_t is 3-channel from some other refinement, use as is
        t_broadcast = refined_t


    J = (image.astype(np.float32) - A) / np.maximum(t_broadcast, t0) + A
    J = np.clip(J, 0, 255).astype(np.uint8)
    return J

# %%
def apply_clahe(image_bgr, clip_limit=2.0, tile_grid_size=(8,8)):
    if image_bgr is None:
        print("Error: CLAHE received a None image.")
        return None
    lab = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe_obj = cv2.createCLAHE(clipLimit=clip_limit, tileGridSize=tile_grid_size)
    cl = clahe_obj.apply(l)
    limg = cv2.merge((cl, a, b))
    final_clahe = cv2.cvtColor(limg, cv2.COLOR_LAB2BGR)
    return final_clahe

# %%
if __name__ == "__main__":
    # --- Configuration ---
    input_image_dir = 'Foggy_Cityscapes/Dense_Fog'  # <--- CHANGE THIS TO YOUR INPUT FOLDER
    output_dcp_dir = 'Clean_outputs/DCP'
    output_clahe_dir = 'Clean_outputs/CLAHE'
    output_csv_file = 'Clean_outputs/metrics.csv'

    dcp_patch_size = 15
    dcp_omega = 0.90      # Might need to be slightly lower for aggressive dehazing
    dcp_t0 = 0.1
    dcp_refine_radius = 50 # Increased radius for smoother transmission

    clahe_clip_limit = 2.0
    clahe_tile_grid = (8, 8)


    # Create output directories if they don't exist
    os.makedirs(output_dcp_dir, exist_ok=True)
    os.makedirs(output_clahe_dir, exist_ok=True)
    os.makedirs(os.path.dirname(output_csv_file), exist_ok=True)


    # Prepare CSV file
    csv_header = [
        'filename',
        'original_entropy',
        'dcp_processed', 'dcp_entropy',
        'clahe_processed', 'clahe_entropy'
    ]
    
    # Check if input directory exists
    if not os.path.isdir(input_image_dir):
        print(f"Error: Input directory '{input_image_dir}' does not exist. Please create it and add your images.")
        exit()

    image_files = [f for f in os.listdir(input_image_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff'))]
    
    if not image_files:
        print(f"No image files found in '{input_image_dir}'.")
        exit()
        
    print(f"Found {len(image_files)} images to process in '{input_image_dir}'.")

    with open(output_csv_file, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(csv_header)

        for i, filename in enumerate(image_files):
            print(f"\nProcessing image {i+1}/{len(image_files)}: {filename}")
            input_path = os.path.join(input_image_dir, filename)
            
            original_image = cv2.imread(input_path)
            if original_image is None:
                print(f"  Error: Could not read original image {filename}. Skipping.")
                writer.writerow([filename, 'N/A', False, 'N/A', False, 'N/A'])
                continue

            original_gray = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)
            original_entropy = calculate_entropy(original_gray)

            row_data = {
                'filename': filename,
                'original_entropy': f"{original_entropy:.4f}" if original_entropy is not None else 'N/A',
                'dcp_processed': False, 'dcp_entropy': 'N/A',
                'clahe_processed': False, 'clahe_entropy': 'N/A'
            }

            # 1. Dark Channel Prior Dehazing
            print(f"  Applying DCP...")
            try:
                dehazed_dcp_image = dehaze_dcp(original_image.copy(),
                                               patch_size=dcp_patch_size,
                                               omega=dcp_omega,
                                               t0=dcp_t0,
                                               refine_radius=dcp_refine_radius)
                if dehazed_dcp_image is not None:
                    output_path_dcp = os.path.join(output_dcp_dir, filename)
                    cv2.imwrite(output_path_dcp, dehazed_dcp_image)
                    dcp_gray = cv2.cvtColor(dehazed_dcp_image, cv2.COLOR_BGR2GRAY)
                    dcp_entropy = calculate_entropy(dcp_gray)
                    row_data['dcp_processed'] = True
                    row_data['dcp_entropy'] = f"{dcp_entropy:.4f}" if dcp_entropy is not None else 'N/A'
                    print(f"    DCP image saved to {output_path_dcp}")
                else:
                    print(f"    DCP processing failed for {filename}.")
            except Exception as e:
                print(f"    Exception during DCP processing for {filename}: {e}")


            # 2. CLAHE Enhancement
            print(f"  Applying CLAHE...")
            try:
                clahe_image = apply_clahe(original_image.copy(),
                                          clip_limit=clahe_clip_limit,
                                          tile_grid_size=clahe_tile_grid)
                if clahe_image is not None:
                    output_path_clahe = os.path.join(output_clahe_dir, filename)
                    cv2.imwrite(output_path_clahe, clahe_image)
                    clahe_gray = cv2.cvtColor(clahe_image, cv2.COLOR_BGR2GRAY)
                    clahe_entropy = calculate_entropy(clahe_gray)
                    row_data['clahe_processed'] = True
                    row_data['clahe_entropy'] = f"{clahe_entropy:.4f}" if clahe_entropy is not None else 'N/A'
                    print(f"    CLAHE image saved to {output_path_clahe}")
                else:
                    print(f"    CLAHE processing failed for {filename}.")
            except Exception as e:
                print(f"    Exception during CLAHE processing for {filename}: {e}")

            writer.writerow([
                row_data['filename'],
                row_data['original_entropy'],
                row_data['dcp_processed'], row_data['dcp_entropy'],
                row_data['clahe_processed'], row_data['clahe_entropy']
            ])

    print(f"\n\nBatch processing complete. Processed images saved in respective output folders.")
    print(f"Metrics saved to: {output_csv_file}")
# Out:
# Found 500 images to process in 'Foggy_Cityscapes/Dense_Fog'.
#
# Processing image 1/500: 001.png
#   Applying DCP...
#     Exception during DCP processing for 001.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\001.png
#
# Processing image 2/500: 002.png
#   Applying DCP...
#     Exception during DCP processing for 002.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\002.png
#
# Processing image 3/500: 003.png
#   Applying DCP...
#     Exception during DCP processing for 003.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\003.png
#
# Processing image 4/500: 004.png
#   Applying DCP...
#     Exception during DCP processing for 004.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\004.png
#
# Processing image 5/500: 005.png
#   Applying DCP...
#     Exception during DCP processing for 005.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\005.png
#
# Processing image 6/500: 006.png
#   Applying DCP...
#     Exception during DCP processing for 006.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\006.png
#
# Processing image 7/500: 007.png
#   Applying DCP...
#     Exception during DCP processing for 007.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\007.png
#
# Processing image 8/500: 008.png
#   Applying DCP...
#     Exception during DCP processing for 008.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\008.png
#
# Processing image 9/500: 009.png
#   Applying DCP...
#     Exception during DCP processing for 009.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\009.png
#
# Processing image 10/500: 010.png
#   Applying DCP...
#     Exception during DCP processing for 010.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\010.png
#
# Processing image 11/500: 011.png
#   Applying DCP...
#     Exception during DCP processing for 011.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\011.png
#
# Processing image 12/500: 012.png
#   Applying DCP...
#     Exception during DCP processing for 012.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\012.png
#
# Processing image 13/500: 013.png
#   Applying DCP...
#     Exception during DCP processing for 013.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\013.png
#
# Processing image 14/500: 014.png
#   Applying DCP...
#     Exception during DCP processing for 014.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\014.png
#
# Processing image 15/500: 015.png
#   Applying DCP...
#     Exception during DCP processing for 015.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\015.png
#
# Processing image 16/500: 016.png
#   Applying DCP...
#     Exception during DCP processing for 016.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\016.png
#
# Processing image 17/500: 017.png
#   Applying DCP...
#     Exception during DCP processing for 017.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\017.png
#
# Processing image 18/500: 018.png
#   Applying DCP...
#     Exception during DCP processing for 018.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\018.png
#
# Processing image 19/500: 019.png
#   Applying DCP...
#     Exception during DCP processing for 019.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\019.png
#
# Processing image 20/500: 020.png
#   Applying DCP...
#     Exception during DCP processing for 020.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\020.png
#
# Processing image 21/500: 021.png
#   Applying DCP...
#     Exception during DCP processing for 021.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\021.png
#
# Processing image 22/500: 022.png
#   Applying DCP...
#     Exception during DCP processing for 022.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\022.png
#
# Processing image 23/500: 023.png
#   Applying DCP...
#     Exception during DCP processing for 023.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\023.png
#
# Processing image 24/500: 024.png
#   Applying DCP...
#     Exception during DCP processing for 024.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\024.png
#
# Processing image 25/500: 025.png
#   Applying DCP...
#     Exception during DCP processing for 025.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\025.png
#
# Processing image 26/500: 026.png
#   Applying DCP...
#     Exception during DCP processing for 026.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\026.png
#
# Processing image 27/500: 027.png
#   Applying DCP...
#     Exception during DCP processing for 027.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\027.png
#
# Processing image 28/500: 028.png
#   Applying DCP...
#     Exception during DCP processing for 028.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\028.png
#
# Processing image 29/500: 029.png
#   Applying DCP...
#     Exception during DCP processing for 029.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\029.png
#
# Processing image 30/500: 030.png
#   Applying DCP...
#     Exception during DCP processing for 030.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\030.png
#
# Processing image 31/500: 031.png
#   Applying DCP...
#     Exception during DCP processing for 031.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\031.png
#
# Processing image 32/500: 032.png
#   Applying DCP...
#     Exception during DCP processing for 032.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\032.png
#
# Processing image 33/500: 033.png
#   Applying DCP...
#     Exception during DCP processing for 033.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\033.png
#
# Processing image 34/500: 034.png
#   Applying DCP...
#     Exception during DCP processing for 034.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\034.png
#
# Processing image 35/500: 035.png
#   Applying DCP...
#     Exception during DCP processing for 035.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\035.png
#
# Processing image 36/500: 036.png
#   Applying DCP...
#     Exception during DCP processing for 036.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\036.png
#
# Processing image 37/500: 037.png
#   Applying DCP...
#     Exception during DCP processing for 037.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\037.png
#
# Processing image 38/500: 038.png
#   Applying DCP...
#     Exception during DCP processing for 038.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\038.png
#
# Processing image 39/500: 039.png
#   Applying DCP...
#     Exception during DCP processing for 039.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\039.png
#
# Processing image 40/500: 040.png
#   Applying DCP...
#     Exception during DCP processing for 040.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\040.png
#
# Processing image 41/500: 041.png
#   Applying DCP...
#     Exception during DCP processing for 041.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\041.png
#
# Processing image 42/500: 042.png
#   Applying DCP...
#     Exception during DCP processing for 042.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\042.png
#
# Processing image 43/500: 043.png
#   Applying DCP...
#     Exception during DCP processing for 043.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\043.png
#
# Processing image 44/500: 044.png
#   Applying DCP...
#     Exception during DCP processing for 044.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\044.png
#
# Processing image 45/500: 045.png
#   Applying DCP...
#     Exception during DCP processing for 045.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\045.png
#
# Processing image 46/500: 046.png
#   Applying DCP...
#     Exception during DCP processing for 046.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\046.png
#
# Processing image 47/500: 047.png
#   Applying DCP...
#     Exception during DCP processing for 047.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\047.png
#
# Processing image 48/500: 048.png
#   Applying DCP...
#     Exception during DCP processing for 048.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\048.png
#
# Processing image 49/500: 049.png
#   Applying DCP...
#     Exception during DCP processing for 049.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\049.png
#
# Processing image 50/500: 050.png
#   Applying DCP...
#     Exception during DCP processing for 050.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\050.png
#
# Processing image 51/500: 051.png
#   Applying DCP...
#     Exception during DCP processing for 051.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\051.png
#
# Processing image 52/500: 052.png
#   Applying DCP...
#     Exception during DCP processing for 052.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\052.png
#
# Processing image 53/500: 053.png
#   Applying DCP...
#     Exception during DCP processing for 053.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\053.png
#
# Processing image 54/500: 054.png
#   Applying DCP...
#     Exception during DCP processing for 054.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\054.png
#
# Processing image 55/500: 055.png
#   Applying DCP...
#     Exception during DCP processing for 055.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\055.png
#
# Processing image 56/500: 056.png
#   Applying DCP...
#     Exception during DCP processing for 056.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\056.png
#
# Processing image 57/500: 057.png
#   Applying DCP...
#     Exception during DCP processing for 057.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\057.png
#
# Processing image 58/500: 058.png
#   Applying DCP...
#     Exception during DCP processing for 058.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\058.png
#
# Processing image 59/500: 059.png
#   Applying DCP...
#     Exception during DCP processing for 059.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\059.png
#
# Processing image 60/500: 060.png
#   Applying DCP...
#     Exception during DCP processing for 060.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\060.png
#
# Processing image 61/500: 061.png
#   Applying DCP...
#     Exception during DCP processing for 061.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\061.png
#
# Processing image 62/500: 062.png
#   Applying DCP...
#     Exception during DCP processing for 062.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\062.png
#
# Processing image 63/500: 063.png
#   Applying DCP...
#     Exception during DCP processing for 063.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\063.png
#
# Processing image 64/500: 064.png
#   Applying DCP...
#     Exception during DCP processing for 064.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\064.png
#
# Processing image 65/500: 065.png
#   Applying DCP...
#     Exception during DCP processing for 065.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\065.png
#
# Processing image 66/500: 066.png
#   Applying DCP...
#     Exception during DCP processing for 066.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\066.png
#
# Processing image 67/500: 067.png
#   Applying DCP...
#     Exception during DCP processing for 067.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\067.png
#
# Processing image 68/500: 068.png
#   Applying DCP...
#     Exception during DCP processing for 068.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\068.png
#
# Processing image 69/500: 069.png
#   Applying DCP...
#     Exception during DCP processing for 069.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\069.png
#
# Processing image 70/500: 070.png
#   Applying DCP...
#     Exception during DCP processing for 070.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\070.png
#
# Processing image 71/500: 071.png
#   Applying DCP...
#     Exception during DCP processing for 071.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\071.png
#
# Processing image 72/500: 072.png
#   Applying DCP...
#     Exception during DCP processing for 072.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\072.png
#
# Processing image 73/500: 073.png
#   Applying DCP...
#     Exception during DCP processing for 073.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\073.png
#
# Processing image 74/500: 074.png
#   Applying DCP...
#     Exception during DCP processing for 074.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\074.png
#
# Processing image 75/500: 075.png
#   Applying DCP...
#     Exception during DCP processing for 075.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\075.png
#
# Processing image 76/500: 076.png
#   Applying DCP...
#     Exception during DCP processing for 076.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\076.png
#
# Processing image 77/500: 077.png
#   Applying DCP...
#     Exception during DCP processing for 077.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\077.png
#
# Processing image 78/500: 078.png
#   Applying DCP...
#     Exception during DCP processing for 078.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\078.png
#
# Processing image 79/500: 079.png
#   Applying DCP...
#     Exception during DCP processing for 079.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\079.png
#
# Processing image 80/500: 080.png
#   Applying DCP...
#     Exception during DCP processing for 080.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\080.png
#
# Processing image 81/500: 081.png
#   Applying DCP...
#     Exception during DCP processing for 081.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\081.png
#
# Processing image 82/500: 082.png
#   Applying DCP...
#     Exception during DCP processing for 082.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\082.png
#
# Processing image 83/500: 083.png
#   Applying DCP...
#     Exception during DCP processing for 083.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\083.png
#
# Processing image 84/500: 084.png
#   Applying DCP...
#     Exception during DCP processing for 084.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\084.png
#
# Processing image 85/500: 085.png
#   Applying DCP...
#     Exception during DCP processing for 085.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\085.png
#
# Processing image 86/500: 086.png
#   Applying DCP...
#     Exception during DCP processing for 086.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\086.png
#
# Processing image 87/500: 087.png
#   Applying DCP...
#     Exception during DCP processing for 087.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\087.png
#
# Processing image 88/500: 088.png
#   Applying DCP...
#     Exception during DCP processing for 088.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\088.png
#
# Processing image 89/500: 089.png
#   Applying DCP...
#     Exception during DCP processing for 089.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\089.png
#
# Processing image 90/500: 090.png
#   Applying DCP...
#     Exception during DCP processing for 090.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\090.png
#
# Processing image 91/500: 091.png
#   Applying DCP...
#     Exception during DCP processing for 091.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\091.png
#
# Processing image 92/500: 092.png
#   Applying DCP...
#     Exception during DCP processing for 092.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\092.png
#
# Processing image 93/500: 093.png
#   Applying DCP...
#     Exception during DCP processing for 093.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\093.png
#
# Processing image 94/500: 094.png
#   Applying DCP...
#     Exception during DCP processing for 094.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\094.png
#
# Processing image 95/500: 095.png
#   Applying DCP...
#     Exception during DCP processing for 095.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\095.png
#
# Processing image 96/500: 096.png
#   Applying DCP...
#     Exception during DCP processing for 096.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\096.png
#
# Processing image 97/500: 097.png
#   Applying DCP...
#     Exception during DCP processing for 097.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\097.png
#
# Processing image 98/500: 098.png
#   Applying DCP...
#     Exception during DCP processing for 098.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\098.png
#
# Processing image 99/500: 099.png
#   Applying DCP...
#     Exception during DCP processing for 099.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\099.png
#
# Processing image 100/500: 100.png
#   Applying DCP...
#     Exception during DCP processing for 100.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\100.png
#
# Processing image 101/500: 101.png
#   Applying DCP...
#     Exception during DCP processing for 101.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\101.png
#
# Processing image 102/500: 102.png
#   Applying DCP...
#     Exception during DCP processing for 102.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\102.png
#
# Processing image 103/500: 103.png
#   Applying DCP...
#     Exception during DCP processing for 103.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\103.png
#
# Processing image 104/500: 104.png
#   Applying DCP...
#     Exception during DCP processing for 104.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\104.png
#
# Processing image 105/500: 105.png
#   Applying DCP...
#     Exception during DCP processing for 105.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\105.png
#
# Processing image 106/500: 106.png
#   Applying DCP...
#     Exception during DCP processing for 106.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\106.png
#
# Processing image 107/500: 107.png
#   Applying DCP...
#     Exception during DCP processing for 107.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\107.png
#
# Processing image 108/500: 108.png
#   Applying DCP...
#     Exception during DCP processing for 108.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\108.png
#
# Processing image 109/500: 109.png
#   Applying DCP...
#     Exception during DCP processing for 109.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\109.png
#
# Processing image 110/500: 110.png
#   Applying DCP...
#     Exception during DCP processing for 110.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\110.png
#
# Processing image 111/500: 111.png
#   Applying DCP...
#     Exception during DCP processing for 111.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\111.png
#
# Processing image 112/500: 112.png
#   Applying DCP...
#     Exception during DCP processing for 112.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\112.png
#
# Processing image 113/500: 113.png
#   Applying DCP...
#     Exception during DCP processing for 113.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\113.png
#
# Processing image 114/500: 114.png
#   Applying DCP...
#     Exception during DCP processing for 114.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\114.png
#
# Processing image 115/500: 115.png
#   Applying DCP...
#     Exception during DCP processing for 115.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\115.png
#
# Processing image 116/500: 116.png
#   Applying DCP...
#     Exception during DCP processing for 116.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\116.png
#
# Processing image 117/500: 117.png
#   Applying DCP...
#     Exception during DCP processing for 117.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\117.png
#
# Processing image 118/500: 118.png
#   Applying DCP...
#     Exception during DCP processing for 118.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\118.png
#
# Processing image 119/500: 119.png
#   Applying DCP...
#     Exception during DCP processing for 119.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\119.png
#
# Processing image 120/500: 120.png
#   Applying DCP...
#     Exception during DCP processing for 120.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\120.png
#
# Processing image 121/500: 121.png
#   Applying DCP...
#     Exception during DCP processing for 121.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\121.png
#
# Processing image 122/500: 122.png
#   Applying DCP...
#     Exception during DCP processing for 122.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\122.png
#
# Processing image 123/500: 123.png
#   Applying DCP...
#     Exception during DCP processing for 123.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\123.png
#
# Processing image 124/500: 124.png
#   Applying DCP...
#     Exception during DCP processing for 124.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\124.png
#
# Processing image 125/500: 125.png
#   Applying DCP...
#     Exception during DCP processing for 125.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\125.png
#
# Processing image 126/500: 126.png
#   Applying DCP...
#     Exception during DCP processing for 126.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\126.png
#
# Processing image 127/500: 127.png
#   Applying DCP...
#     Exception during DCP processing for 127.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\127.png
#
# Processing image 128/500: 128.png
#   Applying DCP...
#     Exception during DCP processing for 128.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\128.png
#
# Processing image 129/500: 129.png
#   Applying DCP...
#     Exception during DCP processing for 129.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\129.png
#
# Processing image 130/500: 130.png
#   Applying DCP...
#     Exception during DCP processing for 130.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\130.png
#
# Processing image 131/500: 131.png
#   Applying DCP...
#     Exception during DCP processing for 131.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\131.png
#
# Processing image 132/500: 132.png
#   Applying DCP...
#     Exception during DCP processing for 132.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\132.png
#
# Processing image 133/500: 133.png
#   Applying DCP...
#     Exception during DCP processing for 133.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\133.png
#
# Processing image 134/500: 134.png
#   Applying DCP...
#     Exception during DCP processing for 134.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\134.png
#
# Processing image 135/500: 135.png
#   Applying DCP...
#     Exception during DCP processing for 135.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\135.png
#
# Processing image 136/500: 136.png
#   Applying DCP...
#     Exception during DCP processing for 136.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\136.png
#
# Processing image 137/500: 137.png
#   Applying DCP...
#     Exception during DCP processing for 137.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\137.png
#
# Processing image 138/500: 138.png
#   Applying DCP...
#     Exception during DCP processing for 138.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\138.png
#
# Processing image 139/500: 139.png
#   Applying DCP...
#     Exception during DCP processing for 139.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\139.png
#
# Processing image 140/500: 140.png
#   Applying DCP...
#     Exception during DCP processing for 140.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\140.png
#
# Processing image 141/500: 141.png
#   Applying DCP...
#     Exception during DCP processing for 141.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\141.png
#
# Processing image 142/500: 142.png
#   Applying DCP...
#     Exception during DCP processing for 142.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\142.png
#
# Processing image 143/500: 143.png
#   Applying DCP...
#     Exception during DCP processing for 143.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\143.png
#
# Processing image 144/500: 144.png
#   Applying DCP...
#     Exception during DCP processing for 144.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\144.png
#
# Processing image 145/500: 145.png
#   Applying DCP...
#     Exception during DCP processing for 145.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\145.png
#
# Processing image 146/500: 146.png
#   Applying DCP...
#     Exception during DCP processing for 146.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\146.png
#
# Processing image 147/500: 147.png
#   Applying DCP...
#     Exception during DCP processing for 147.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\147.png
#
# Processing image 148/500: 148.png
#   Applying DCP...
#     Exception during DCP processing for 148.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\148.png
#
# Processing image 149/500: 149.png
#   Applying DCP...
#     Exception during DCP processing for 149.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\149.png
#
# Processing image 150/500: 150.png
#   Applying DCP...
#     Exception during DCP processing for 150.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\150.png
#
# Processing image 151/500: 151.png
#   Applying DCP...
#     Exception during DCP processing for 151.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\151.png
#
# Processing image 152/500: 152.png
#   Applying DCP...
#     Exception during DCP processing for 152.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\152.png
#
# Processing image 153/500: 153.png
#   Applying DCP...
#     Exception during DCP processing for 153.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\153.png
#
# Processing image 154/500: 154.png
#   Applying DCP...
#     Exception during DCP processing for 154.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\154.png
#
# Processing image 155/500: 155.png
#   Applying DCP...
#     Exception during DCP processing for 155.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\155.png
#
# Processing image 156/500: 156.png
#   Applying DCP...
#     Exception during DCP processing for 156.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\156.png
#
# Processing image 157/500: 157.png
#   Applying DCP...
#     Exception during DCP processing for 157.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\157.png
#
# Processing image 158/500: 158.png
#   Applying DCP...
#     Exception during DCP processing for 158.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\158.png
#
# Processing image 159/500: 159.png
#   Applying DCP...
#     Exception during DCP processing for 159.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\159.png
#
# Processing image 160/500: 160.png
#   Applying DCP...
#     Exception during DCP processing for 160.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\160.png
#
# Processing image 161/500: 161.png
#   Applying DCP...
#     Exception during DCP processing for 161.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\161.png
#
# Processing image 162/500: 162.png
#   Applying DCP...
#     Exception during DCP processing for 162.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\162.png
#
# Processing image 163/500: 163.png
#   Applying DCP...
#     Exception during DCP processing for 163.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\163.png
#
# Processing image 164/500: 164.png
#   Applying DCP...
#     Exception during DCP processing for 164.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\164.png
#
# Processing image 165/500: 165.png
#   Applying DCP...
#     Exception during DCP processing for 165.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\165.png
#
# Processing image 166/500: 166.png
#   Applying DCP...
#     Exception during DCP processing for 166.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\166.png
#
# Processing image 167/500: 167.png
#   Applying DCP...
#     Exception during DCP processing for 167.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\167.png
#
# Processing image 168/500: 168.png
#   Applying DCP...
#     Exception during DCP processing for 168.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\168.png
#
# Processing image 169/500: 169.png
#   Applying DCP...
#     Exception during DCP processing for 169.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\169.png
#
# Processing image 170/500: 170.png
#   Applying DCP...
#     Exception during DCP processing for 170.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\170.png
#
# Processing image 171/500: 171.png
#   Applying DCP...
#     Exception during DCP processing for 171.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\171.png
#
# Processing image 172/500: 172.png
#   Applying DCP...
#     Exception during DCP processing for 172.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\172.png
#
# Processing image 173/500: 173.png
#   Applying DCP...
#     Exception during DCP processing for 173.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\173.png
#
# Processing image 174/500: 174.png
#   Applying DCP...
#     Exception during DCP processing for 174.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\174.png
#
# Processing image 175/500: 175.png
#   Applying DCP...
#     Exception during DCP processing for 175.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\175.png
#
# Processing image 176/500: 176.png
#   Applying DCP...
#     Exception during DCP processing for 176.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\176.png
#
# Processing image 177/500: 177.png
#   Applying DCP...
#     Exception during DCP processing for 177.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\177.png
#
# Processing image 178/500: 178.png
#   Applying DCP...
#     Exception during DCP processing for 178.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\178.png
#
# Processing image 179/500: 179.png
#   Applying DCP...
#     Exception during DCP processing for 179.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\179.png
#
# Processing image 180/500: 180.png
#   Applying DCP...
#     Exception during DCP processing for 180.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\180.png
#
# Processing image 181/500: 181.png
#   Applying DCP...
#     Exception during DCP processing for 181.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\181.png
#
# Processing image 182/500: 182.png
#   Applying DCP...
#     Exception during DCP processing for 182.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\182.png
#
# Processing image 183/500: 183.png
#   Applying DCP...
#     Exception during DCP processing for 183.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\183.png
#
# Processing image 184/500: 184.png
#   Applying DCP...
#     Exception during DCP processing for 184.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\184.png
#
# Processing image 185/500: 185.png
#   Applying DCP...
#     Exception during DCP processing for 185.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\185.png
#
# Processing image 186/500: 186.png
#   Applying DCP...
#     Exception during DCP processing for 186.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\186.png
#
# Processing image 187/500: 187.png
#   Applying DCP...
#     Exception during DCP processing for 187.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\187.png
#
# Processing image 188/500: 188.png
#   Applying DCP...
#     Exception during DCP processing for 188.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\188.png
#
# Processing image 189/500: 189.png
#   Applying DCP...
#     Exception during DCP processing for 189.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\189.png
#
# Processing image 190/500: 190.png
#   Applying DCP...
#     Exception during DCP processing for 190.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\190.png
#
# Processing image 191/500: 191.png
#   Applying DCP...
#     Exception during DCP processing for 191.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\191.png
#
# Processing image 192/500: 192.png
#   Applying DCP...
#     Exception during DCP processing for 192.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\192.png
#
# Processing image 193/500: 193.png
# ...
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\437.png
#
# Processing image 438/500: 438.png
#   Applying DCP...
#     Exception during DCP processing for 438.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\438.png
#
# Processing image 439/500: 439.png
#   Applying DCP...
#     Exception during DCP processing for 439.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\439.png
#
# Processing image 440/500: 440.png
#   Applying DCP...
#     Exception during DCP processing for 440.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\440.png
#
# Processing image 441/500: 441.png
#   Applying DCP...
#     Exception during DCP processing for 441.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\441.png
#
# Processing image 442/500: 442.png
#   Applying DCP...
#     Exception during DCP processing for 442.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\442.png
#
# Processing image 443/500: 443.png
#   Applying DCP...
#     Exception during DCP processing for 443.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\443.png
#
# Processing image 444/500: 444.png
#   Applying DCP...
#     Exception during DCP processing for 444.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\444.png
#
# Processing image 445/500: 445.png
#   Applying DCP...
#     Exception during DCP processing for 445.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\445.png
#
# Processing image 446/500: 446.png
#   Applying DCP...
#     Exception during DCP processing for 446.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\446.png
#
# Processing image 447/500: 447.png
#   Applying DCP...
#     Exception during DCP processing for 447.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\447.png
#
# Processing image 448/500: 448.png
#   Applying DCP...
#     Exception during DCP processing for 448.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\448.png
#
# Processing image 449/500: 449.png
#   Applying DCP...
#     Exception during DCP processing for 449.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\449.png
#
# Processing image 450/500: 450.png
#   Applying DCP...
#     Exception during DCP processing for 450.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\450.png
#
# Processing image 451/500: 451.png
#   Applying DCP...
#     Exception during DCP processing for 451.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\451.png
#
# Processing image 452/500: 452.png
#   Applying DCP...
#     Exception during DCP processing for 452.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\452.png
#
# Processing image 453/500: 453.png
#   Applying DCP...
#     Exception during DCP processing for 453.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\453.png
#
# Processing image 454/500: 454.png
#   Applying DCP...
#     Exception during DCP processing for 454.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\454.png
#
# Processing image 455/500: 455.png
#   Applying DCP...
#     Exception during DCP processing for 455.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\455.png
#
# Processing image 456/500: 456.png
#   Applying DCP...
#     Exception during DCP processing for 456.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\456.png
#
# Processing image 457/500: 457.png
#   Applying DCP...
#     Exception during DCP processing for 457.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\457.png
#
# Processing image 458/500: 458.png
#   Applying DCP...
#     Exception during DCP processing for 458.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\458.png
#
# Processing image 459/500: 459.png
#   Applying DCP...
#     Exception during DCP processing for 459.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\459.png
#
# Processing image 460/500: 460.png
#   Applying DCP...
#     Exception during DCP processing for 460.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\460.png
#
# Processing image 461/500: 461.png
#   Applying DCP...
#     Exception during DCP processing for 461.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\461.png
#
# Processing image 462/500: 462.png
#   Applying DCP...
#     Exception during DCP processing for 462.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\462.png
#
# Processing image 463/500: 463.png
#   Applying DCP...
#     Exception during DCP processing for 463.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\463.png
#
# Processing image 464/500: 464.png
#   Applying DCP...
#     Exception during DCP processing for 464.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\464.png
#
# Processing image 465/500: 465.png
#   Applying DCP...
#     Exception during DCP processing for 465.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\465.png
#
# Processing image 466/500: 466.png
#   Applying DCP...
#     Exception during DCP processing for 466.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\466.png
#
# Processing image 467/500: 467.png
#   Applying DCP...
#     Exception during DCP processing for 467.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\467.png
#
# Processing image 468/500: 468.png
#   Applying DCP...
#     Exception during DCP processing for 468.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\468.png
#
# Processing image 469/500: 469.png
#   Applying DCP...
#     Exception during DCP processing for 469.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\469.png
#
# Processing image 470/500: 470.png
#   Applying DCP...
#     Exception during DCP processing for 470.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\470.png
#
# Processing image 471/500: 471.png
#   Applying DCP...
#     Exception during DCP processing for 471.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\471.png
#
# Processing image 472/500: 472.png
#   Applying DCP...
#     Exception during DCP processing for 472.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\472.png
#
# Processing image 473/500: 473.png
#   Applying DCP...
#     Exception during DCP processing for 473.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\473.png
#
# Processing image 474/500: 474.png
#   Applying DCP...
#     Exception during DCP processing for 474.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\474.png
#
# Processing image 475/500: 475.png
#   Applying DCP...
#     Exception during DCP processing for 475.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\475.png
#
# Processing image 476/500: 476.png
#   Applying DCP...
#     Exception during DCP processing for 476.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\476.png
#
# Processing image 477/500: 477.png
#   Applying DCP...
#     Exception during DCP processing for 477.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\477.png
#
# Processing image 478/500: 478.png
#   Applying DCP...
#     Exception during DCP processing for 478.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\478.png
#
# Processing image 479/500: 479.png
#   Applying DCP...
#     Exception during DCP processing for 479.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\479.png
#
# Processing image 480/500: 480.png
#   Applying DCP...
#     Exception during DCP processing for 480.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\480.png
#
# Processing image 481/500: 481.png
#   Applying DCP...
#     Exception during DCP processing for 481.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\481.png
#
# Processing image 482/500: 482.png
#   Applying DCP...
#     Exception during DCP processing for 482.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\482.png
#
# Processing image 483/500: 483.png
#   Applying DCP...
#     Exception during DCP processing for 483.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\483.png
#
# Processing image 484/500: 484.png
#   Applying DCP...
#     Exception during DCP processing for 484.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\484.png
#
# Processing image 485/500: 485.png
#   Applying DCP...
#     Exception during DCP processing for 485.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\485.png
#
# Processing image 486/500: 486.png
#   Applying DCP...
#     Exception during DCP processing for 486.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\486.png
#
# Processing image 487/500: 487.png
#   Applying DCP...
#     Exception during DCP processing for 487.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\487.png
#
# Processing image 488/500: 488.png
#   Applying DCP...
#     Exception during DCP processing for 488.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\488.png
#
# Processing image 489/500: 489.png
#   Applying DCP...
#     Exception during DCP processing for 489.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\489.png
#
# Processing image 490/500: 490.png
#   Applying DCP...
#     Exception during DCP processing for 490.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\490.png
#
# Processing image 491/500: 491.png
#   Applying DCP...
#     Exception during DCP processing for 491.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\491.png
#
# Processing image 492/500: 492.png
#   Applying DCP...
#     Exception during DCP processing for 492.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\492.png
#
# Processing image 493/500: 493.png
#   Applying DCP...
#     Exception during DCP processing for 493.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\493.png
#
# Processing image 494/500: 494.png
#   Applying DCP...
#     Exception during DCP processing for 494.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\494.png
#
# Processing image 495/500: 495.png
#   Applying DCP...
#     Exception during DCP processing for 495.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\495.png
#
# Processing image 496/500: 496.png
#   Applying DCP...
#     Exception during DCP processing for 496.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\496.png
#
# Processing image 497/500: 497.png
#   Applying DCP...
#     Exception during DCP processing for 497.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\497.png
#
# Processing image 498/500: 498.png
#   Applying DCP...
#     Exception during DCP processing for 498.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\498.png
#
# Processing image 499/500: 499.png
#   Applying DCP...
#     Exception during DCP processing for 499.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\499.png
#
# Processing image 500/500: 500.png
#   Applying DCP...
#     Exception during DCP processing for 500.png: cannot access local variable 'cv2' where it is not associated with a value
#   Applying CLAHE...
#     CLAHE image saved to Clean_outputs/CLAHE\500.png
#
#
# Batch processing complete. Processed images saved in respective output folders.
# Metrics saved to: Clean_outputs/metrics.csv

# %%
pip install onnx onnxruntime
# Out:
# Requirement already satisfied: onnx in c:\users\korra\anaconda3\lib\site-packages (1.17.0)Note: you may need to restart the kernel to use updated packages.
#
# Collecting onnxruntime
#   Downloading onnxruntime-1.22.0-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy>=1.20 in c:\users\korra\anaconda3\lib\site-packages (from onnx) (1.26.4)
# Requirement already satisfied: protobuf>=3.20.2 in c:\users\korra\anaconda3\lib\site-packages (from onnx) (4.24.4)
# Collecting coloredlogs (from onnxruntime)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime)
#   Using cached flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: packaging in c:\users\korra\anaconda3\lib\site-packages (from onnxruntime) (24.1)
# Requirement already satisfied: sympy in c:\users\korra\anaconda3\lib\site-packages (from onnxruntime) (1.14.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\korra\anaconda3\lib\site-packages (from sympy->onnxruntime) (1.3.0)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime)
#   Using cached pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Downloading onnxruntime-1.22.0-cp312-cp312-win_amd64.whl (12.7 MB)
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.7 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.7 MB 2.1 MB/s eta 0:00:06
#    - -------------------------------------- 0.5/12.7 MB 2.1 MB/s eta 0:00:06
#    -- ------------------------------------- 0.8/12.7 MB 931.2 kB/s eta 0:00:13
#    ---- ----------------------------------- 1.3/12.7 MB 1.2 MB/s eta 0:00:10
#    ---- ----------------------------------- 1.3/12.7 MB 1.2 MB/s eta 0:00:10
#    ----- ---------------------------------- 1.8/12.7 MB 1.3 MB/s eta 0:00:09
#    ------ --------------------------------- 2.1/12.7 MB 1.3 MB/s eta 0:00:09
#    ------- -------------------------------- 2.4/12.7 MB 1.3 MB/s eta 0:00:08
#    -------- ------------------------------- 2.6/12.7 MB 1.3 MB/s eta 0:00:08
#    --------- ------------------------------ 3.1/12.7 MB 1.4 MB/s eta 0:00:08
#    ---------- ----------------------------- 3.4/12.7 MB 1.4 MB/s eta 0:00:07
#    ----------- ---------------------------- 3.7/12.7 MB 1.4 MB/s eta 0:00:07
#    ------------- -------------------------- 4.2/12.7 MB 1.4 MB/s eta 0:00:06
#    -------------- ------------------------- 4.5/12.7 MB 1.4 MB/s eta 0:00:06
#    -------------- ------------------------- 4.7/12.7 MB 1.4 MB/s eta 0:00:06
#    --------------- ------------------------ 5.0/12.7 MB 1.4 MB/s eta 0:00:06
#    ----------------- ---------------------- 5.5/12.7 MB 1.5 MB/s eta 0:00:05
#    ------------------ --------------------- 5.8/12.7 MB 1.5 MB/s eta 0:00:05
#    ------------------- -------------------- 6.0/12.7 MB 1.5 MB/s eta 0:00:05
#    -------------------- ------------------- 6.6/12.7 MB 1.5 MB/s eta 0:00:05
#    ---------------------- ----------------- 7.1/12.7 MB 1.6 MB/s eta 0:00:04
#    ----------------------- ---------------- 7.3/12.7 MB 1.6 MB/s eta 0:00:04
#    ----------------------- ---------------- 7.6/12.7 MB 1.6 MB/s eta 0:00:04
#    ------------------------- -------------- 8.1/12.7 MB 1.6 MB/s eta 0:00:03
#    --------------------------- ------------ 8.7/12.7 MB 1.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 8.9/12.7 MB 1.6 MB/s eta 0:00:03
#    ----------------------------- ---------- 9.4/12.7 MB 1.6 MB/s eta 0:00:02
#    ------------------------------- -------- 10.0/12.7 MB 1.7 MB/s eta 0:00:02
#    -------------------------------- ------- 10.2/12.7 MB 1.7 MB/s eta 0:00:02
#    --------------------------------- ------ 10.7/12.7 MB 1.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.3/12.7 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.7 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 12.1/12.7 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.7/12.7 MB 1.7 MB/s eta 0:00:00
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Installing collected packages: flatbuffers, pyreadline3, humanfriendly, coloredlogs, onnxruntime
# Successfully installed coloredlogs-15.0.1 flatbuffers-25.2.10 humanfriendly-10.0 onnxruntime-1.22.0 pyreadline3-3.5.4

# %%
yolo export model=runs/detect/your_foggy_yolov8s_run1/weights/best.pt format=onnx imgsz=640 half=True
